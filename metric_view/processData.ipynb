# %%
import subprocess

#Params
datasetPath = "../datasets/"
dataPath = "./data_clustered/"
resultPath = "./results/"
filenames = ["Dune","Apache"]
perf="perf"

n_lines=[]
for k,filename in enumerate(filenames):
    n_lines.append(int(subprocess.check_output("echo $(wc -l < "+datasetPath+filename+".csv)", shell=True)))

#Params for sensitivity
NBINS = 40 # Number of vertical bins for threshold
NSUBS = 10 # Number of training sets to average on
srm = 1 # Minimum sampling size
srM=[]
srs = []
for k,filename in enumerate(filenames):
    srM.append(int(subprocess.check_output("echo $(wc -l < "+datasetPath+filename+".csv)", shell=True))) # Maximum sampling size
    srs.append(srM[k]//100) # Sampling step between two iterations

oracle = [0.2,0.5,0.8]

# %%
import sys, os
import pandas as pd
from sklearn import tree

def sensitivity(datasetPath, dataPath, filename, perf, NBINS, NSUBS, srm, srM, srs, oracle=False):
    
    #If data fodler does not exists
    if not os.path.exists(dataPath):
        try:
            os.makedirs(dataPath)
        except OSError as exc: # Guard against race condition
            if exc.errno != errno.EEXIST:
                raise
    
    
    perf_x264 = ['Watt', 'Energy', 'SSIM', 'PSNR', 'Speed', 'Size', 'Time']
    perf_sac = ['compile-exit', 'compile-real', 'compile-user', 'compile-ioin', 'compile-ioout',
                'compile-maxmem', 'compile-cpu', 'compile-size', 'run-exit',
                'run-real', 'run-user', 'run-maxmem', 'run-cpu']

    d = pd.read_csv(datasetPath+filename+".csv") # Open dataset
    d = d.sort_values(by=perf) # Sort it by perf to get threshold values
    if not oracle:
        thresholds = [d[perf].iloc[i * d.shape[0]//NBINS] for i in range(1, NBINS)]
    else:
        for i in oracle:
            if not os.path.exists(dataPath+str(i)):
                try:
                    os.makedirs(dataPath+str(i))
                except OSError as exc: # Guard against race condition
                    if exc.errno != errno.EEXIST:
                        raise
        thresholds = [d[perf].iloc[int(i * d.shape[0])] for i in oracle]

    # Computation
    for k,t in enumerate(thresholds):
        res = {"sr":[],"t":[],"TN":[],"TP":[],"FN":[],"FP":[]}
        for sr in range(srm,srM,srs):
                print("Computing for sr=%d and t=%.3f..." % (sr, t))
                d["label"] = 0
                d.loc[d[perf] > t, "label"] = 1 # Label with the (current) oracle
                clean = d.drop(perf_sac+perf_x264+["perf"],axis=1,errors="ignore")
                subs = [clean.sample(sr) for i in range(NSUBS)] # Subsample trainsets
                TN = TP = FN = FP = 0 # Counters for classification results
                d["pred"] = 0
                for s in subs: # We cumulate results for each experiment and average later
                    # MACHINE LEARNING PART
                    # Settings are chosen to be the closest to J48 algorithm
                    c = tree.DecisionTreeClassifier(criterion="entropy", min_samples_leaf=2)
                    c.fit(s.drop(["label"],axis=1), s.label)
                    # END OF LEARNING
                    d["pred"] = c.predict(clean.drop(["label"], axis=1)) # Get model's prediction
                    TN += d[(d.label == 0) & (d.pred == 0)].shape[0]
                    TP += d[(d.label == 1) & (d.pred == 1)].shape[0]
                    FN += d[(d.label == 1) & (d.pred == 0)].shape[0]
                    FP += d[(d.label == 0) & (d.pred == 1)].shape[0]
                del d["pred"] # Reset
                # Push the results
                res["sr"].append(sr)
                res["t"].append(t)
                res["TN"].append(TN/NSUBS)
                res["TP"].append(TP/NSUBS)
                res["FN"].append(FN/NSUBS)
                res["FP"].append(FP/NSUBS)
        # Save the result as csv
        pd.DataFrame(res).to_csv(dataPath+"/"+str(oracle[k])+"/"+str(oracle[k])+"-"+filename+".csv", index=False)

# %%
for k,filename in enumerate(filenames):
    #Machine learning part, using data from {filename} file in {datasetPath} folder and writing results in {dataPath} folder
    sensitivity(datasetPath = datasetPath, dataPath = dataPath, filename = filename,
                perf = perf, NBINS = NBINS, NSUBS = NSUBS, srm = srm, srM = srM[k], srs = srs[k], oracle = oracle)
# Out:
# Computing for sr=1 and t=8447.814...
# Computing for sr=24 and t=8447.814...
# Computing for sr=47 and t=8447.814...
# Computing for sr=70 and t=8447.814...
# Computing for sr=93 and t=8447.814...
# Computing for sr=116 and t=8447.814...
# Computing for sr=139 and t=8447.814...
# Computing for sr=162 and t=8447.814...
# Computing for sr=185 and t=8447.814...
# Computing for sr=208 and t=8447.814...
# Computing for sr=231 and t=8447.814...
# Computing for sr=254 and t=8447.814...
# Computing for sr=277 and t=8447.814...
# Computing for sr=300 and t=8447.814...
# Computing for sr=323 and t=8447.814...
# Computing for sr=346 and t=8447.814...
# Computing for sr=369 and t=8447.814...
# Computing for sr=392 and t=8447.814...
# Computing for sr=415 and t=8447.814...
# Computing for sr=438 and t=8447.814...
# Computing for sr=461 and t=8447.814...
# Computing for sr=484 and t=8447.814...
# Computing for sr=507 and t=8447.814...
# Computing for sr=530 and t=8447.814...
# Computing for sr=553 and t=8447.814...
# Computing for sr=576 and t=8447.814...
# Computing for sr=599 and t=8447.814...
# Computing for sr=622 and t=8447.814...
# Computing for sr=645 and t=8447.814...
# Computing for sr=668 and t=8447.814...
# Computing for sr=691 and t=8447.814...
# Computing for sr=714 and t=8447.814...
# Computing for sr=737 and t=8447.814...
# Computing for sr=760 and t=8447.814...
# Computing for sr=783 and t=8447.814...
# Computing for sr=806 and t=8447.814...
# Computing for sr=829 and t=8447.814...
# Computing for sr=852 and t=8447.814...
# Computing for sr=875 and t=8447.814...
# Computing for sr=898 and t=8447.814...
# Computing for sr=921 and t=8447.814...
# Computing for sr=944 and t=8447.814...
# Computing for sr=967 and t=8447.814...
# Computing for sr=990 and t=8447.814...
# Computing for sr=1013 and t=8447.814...
# Computing for sr=1036 and t=8447.814...
# Computing for sr=1059 and t=8447.814...
# Computing for sr=1082 and t=8447.814...
# Computing for sr=1105 and t=8447.814...
# Computing for sr=1128 and t=8447.814...
# Computing for sr=1151 and t=8447.814...
# Computing for sr=1174 and t=8447.814...
# Computing for sr=1197 and t=8447.814...
# Computing for sr=1220 and t=8447.814...
# Computing for sr=1243 and t=8447.814...
# Computing for sr=1266 and t=8447.814...
# Computing for sr=1289 and t=8447.814...
# Computing for sr=1312 and t=8447.814...
# Computing for sr=1335 and t=8447.814...
# Computing for sr=1358 and t=8447.814...
# Computing for sr=1381 and t=8447.814...
# Computing for sr=1404 and t=8447.814...
# Computing for sr=1427 and t=8447.814...
# Computing for sr=1450 and t=8447.814...
# Computing for sr=1473 and t=8447.814...
# Computing for sr=1496 and t=8447.814...
# Computing for sr=1519 and t=8447.814...
# Computing for sr=1542 and t=8447.814...
# Computing for sr=1565 and t=8447.814...
# Computing for sr=1588 and t=8447.814...
# Computing for sr=1611 and t=8447.814...
# Computing for sr=1634 and t=8447.814...
# Computing for sr=1657 and t=8447.814...
# Computing for sr=1680 and t=8447.814...
# Computing for sr=1703 and t=8447.814...
# Computing for sr=1726 and t=8447.814...
# Computing for sr=1749 and t=8447.814...
# Computing for sr=1772 and t=8447.814...
# Computing for sr=1795 and t=8447.814...
# Computing for sr=1818 and t=8447.814...
# Computing for sr=1841 and t=8447.814...
# Computing for sr=1864 and t=8447.814...
# Computing for sr=1887 and t=8447.814...
# Computing for sr=1910 and t=8447.814...
# Computing for sr=1933 and t=8447.814...
# Computing for sr=1956 and t=8447.814...
# Computing for sr=1979 and t=8447.814...
# Computing for sr=2002 and t=8447.814...
# Computing for sr=2025 and t=8447.814...
# Computing for sr=2048 and t=8447.814...
# Computing for sr=2071 and t=8447.814...
# Computing for sr=2094 and t=8447.814...
# Computing for sr=2117 and t=8447.814...
# Computing for sr=2140 and t=8447.814...
# Computing for sr=2163 and t=8447.814...
# Computing for sr=2186 and t=8447.814...
# Computing for sr=2209 and t=8447.814...
# Computing for sr=2232 and t=8447.814...
# Computing for sr=2255 and t=8447.814...
# Computing for sr=2278 and t=8447.814...
# Computing for sr=2301 and t=8447.814...
# Computing for sr=1 and t=10259.975...
# Computing for sr=24 and t=10259.975...
# Computing for sr=47 and t=10259.975...
# Computing for sr=70 and t=10259.975...
# Computing for sr=93 and t=10259.975...
# Computing for sr=116 and t=10259.975...
# Computing for sr=139 and t=10259.975...
# Computing for sr=162 and t=10259.975...
# Computing for sr=185 and t=10259.975...
# Computing for sr=208 and t=10259.975...
# Computing for sr=231 and t=10259.975...
# Computing for sr=254 and t=10259.975...
# Computing for sr=277 and t=10259.975...
# Computing for sr=300 and t=10259.975...
# Computing for sr=323 and t=10259.975...
# Computing for sr=346 and t=10259.975...
# Computing for sr=369 and t=10259.975...
# Computing for sr=392 and t=10259.975...
# Computing for sr=415 and t=10259.975...
# Computing for sr=438 and t=10259.975...
# Computing for sr=461 and t=10259.975...
# Computing for sr=484 and t=10259.975...
# Computing for sr=507 and t=10259.975...
# Computing for sr=530 and t=10259.975...
# Computing for sr=553 and t=10259.975...
# Computing for sr=576 and t=10259.975...
# Computing for sr=599 and t=10259.975...
# Computing for sr=622 and t=10259.975...
# Computing for sr=645 and t=10259.975...
# Computing for sr=668 and t=10259.975...
# Computing for sr=691 and t=10259.975...
# Computing for sr=714 and t=10259.975...
# Computing for sr=737 and t=10259.975...
# Computing for sr=760 and t=10259.975...
# Computing for sr=783 and t=10259.975...
# Computing for sr=806 and t=10259.975...
# Computing for sr=829 and t=10259.975...
# Computing for sr=852 and t=10259.975...
# Computing for sr=875 and t=10259.975...
# Computing for sr=898 and t=10259.975...
# Computing for sr=921 and t=10259.975...
# Computing for sr=944 and t=10259.975...
# Computing for sr=967 and t=10259.975...
# Computing for sr=990 and t=10259.975...
# Computing for sr=1013 and t=10259.975...
# Computing for sr=1036 and t=10259.975...
# Computing for sr=1059 and t=10259.975...
# Computing for sr=1082 and t=10259.975...
# Computing for sr=1105 and t=10259.975...
# Computing for sr=1128 and t=10259.975...
# Computing for sr=1151 and t=10259.975...
# Computing for sr=1174 and t=10259.975...
# Computing for sr=1197 and t=10259.975...
# Computing for sr=1220 and t=10259.975...
# Computing for sr=1243 and t=10259.975...
# Computing for sr=1266 and t=10259.975...
# Computing for sr=1289 and t=10259.975...
# Computing for sr=1312 and t=10259.975...
# Computing for sr=1335 and t=10259.975...
# Computing for sr=1358 and t=10259.975...
# Computing for sr=1381 and t=10259.975...
# Computing for sr=1404 and t=10259.975...
# Computing for sr=1427 and t=10259.975...
# Computing for sr=1450 and t=10259.975...
# Computing for sr=1473 and t=10259.975...
# Computing for sr=1496 and t=10259.975...
# Computing for sr=1519 and t=10259.975...
# Computing for sr=1542 and t=10259.975...
# Computing for sr=1565 and t=10259.975...
# Computing for sr=1588 and t=10259.975...
# Computing for sr=1611 and t=10259.975...
# Computing for sr=1634 and t=10259.975...
# Computing for sr=1657 and t=10259.975...
# Computing for sr=1680 and t=10259.975...
# Computing for sr=1703 and t=10259.975...
# Computing for sr=1726 and t=10259.975...
# Computing for sr=1749 and t=10259.975...
# Computing for sr=1772 and t=10259.975...
# Computing for sr=1795 and t=10259.975...
# Computing for sr=1818 and t=10259.975...
# Computing for sr=1841 and t=10259.975...
# Computing for sr=1864 and t=10259.975...
# Computing for sr=1887 and t=10259.975...
# Computing for sr=1910 and t=10259.975...
# Computing for sr=1933 and t=10259.975...
# Computing for sr=1956 and t=10259.975...
# Computing for sr=1979 and t=10259.975...
# Computing for sr=2002 and t=10259.975...
# Computing for sr=2025 and t=10259.975...
# Computing for sr=2048 and t=10259.975...
# Computing for sr=2071 and t=10259.975...
# Computing for sr=2094 and t=10259.975...
# Computing for sr=2117 and t=10259.975...
# Computing for sr=2140 and t=10259.975...
# Computing for sr=2163 and t=10259.975...
# Computing for sr=2186 and t=10259.975...
# Computing for sr=2209 and t=10259.975...
# Computing for sr=2232 and t=10259.975...
# Computing for sr=2255 and t=10259.975...
# Computing for sr=2278 and t=10259.975...
# Computing for sr=2301 and t=10259.975...
# Computing for sr=1 and t=11656.393...
# Computing for sr=24 and t=11656.393...
# Computing for sr=47 and t=11656.393...
# Computing for sr=70 and t=11656.393...
# Computing for sr=93 and t=11656.393...
# Computing for sr=116 and t=11656.393...
# Computing for sr=139 and t=11656.393...
# Computing for sr=162 and t=11656.393...
# Computing for sr=185 and t=11656.393...
# Computing for sr=208 and t=11656.393...
# Computing for sr=231 and t=11656.393...
# Computing for sr=254 and t=11656.393...
# Computing for sr=277 and t=11656.393...
# Computing for sr=300 and t=11656.393...
# Computing for sr=323 and t=11656.393...
# Computing for sr=346 and t=11656.393...
# Computing for sr=369 and t=11656.393...
# Computing for sr=392 and t=11656.393...
# Computing for sr=415 and t=11656.393...
# Computing for sr=438 and t=11656.393...
# Computing for sr=461 and t=11656.393...
# Computing for sr=484 and t=11656.393...
# Computing for sr=507 and t=11656.393...
# Computing for sr=530 and t=11656.393...
# Computing for sr=553 and t=11656.393...
# Computing for sr=576 and t=11656.393...
# Computing for sr=599 and t=11656.393...
# Computing for sr=622 and t=11656.393...
# Computing for sr=645 and t=11656.393...
# Computing for sr=668 and t=11656.393...
# Computing for sr=691 and t=11656.393...
# Computing for sr=714 and t=11656.393...
# Computing for sr=737 and t=11656.393...
# Computing for sr=760 and t=11656.393...
# Computing for sr=783 and t=11656.393...
# Computing for sr=806 and t=11656.393...
# Computing for sr=829 and t=11656.393...
# Computing for sr=852 and t=11656.393...
# Computing for sr=875 and t=11656.393...
# Computing for sr=898 and t=11656.393...
# Computing for sr=921 and t=11656.393...
# Computing for sr=944 and t=11656.393...
# Computing for sr=967 and t=11656.393...
# Computing for sr=990 and t=11656.393...
# Computing for sr=1013 and t=11656.393...
# Computing for sr=1036 and t=11656.393...
# Computing for sr=1059 and t=11656.393...
# Computing for sr=1082 and t=11656.393...
# Computing for sr=1105 and t=11656.393...
# Computing for sr=1128 and t=11656.393...
# Computing for sr=1151 and t=11656.393...
# Computing for sr=1174 and t=11656.393...
# Computing for sr=1197 and t=11656.393...
# Computing for sr=1220 and t=11656.393...
# Computing for sr=1243 and t=11656.393...
# Computing for sr=1266 and t=11656.393...
# Computing for sr=1289 and t=11656.393...
# Computing for sr=1312 and t=11656.393...
# Computing for sr=1335 and t=11656.393...
# Computing for sr=1358 and t=11656.393...
# Computing for sr=1381 and t=11656.393...
# Computing for sr=1404 and t=11656.393...
# Computing for sr=1427 and t=11656.393...
# Computing for sr=1450 and t=11656.393...
# Computing for sr=1473 and t=11656.393...
# Computing for sr=1496 and t=11656.393...
# Computing for sr=1519 and t=11656.393...
# Computing for sr=1542 and t=11656.393...
# Computing for sr=1565 and t=11656.393...
# Computing for sr=1588 and t=11656.393...
# Computing for sr=1611 and t=11656.393...
# Computing for sr=1634 and t=11656.393...
# Computing for sr=1657 and t=11656.393...
# Computing for sr=1680 and t=11656.393...
# Computing for sr=1703 and t=11656.393...
# Computing for sr=1726 and t=11656.393...
# Computing for sr=1749 and t=11656.393...
# Computing for sr=1772 and t=11656.393...
# Computing for sr=1795 and t=11656.393...
# Computing for sr=1818 and t=11656.393...
# Computing for sr=1841 and t=11656.393...
# Computing for sr=1864 and t=11656.393...
# Computing for sr=1887 and t=11656.393...
# Computing for sr=1910 and t=11656.393...
# Computing for sr=1933 and t=11656.393...
# Computing for sr=1956 and t=11656.393...
# Computing for sr=1979 and t=11656.393...
# Computing for sr=2002 and t=11656.393...
# Computing for sr=2025 and t=11656.393...
# Computing for sr=2048 and t=11656.393...
# Computing for sr=2071 and t=11656.393...
# Computing for sr=2094 and t=11656.393...
# Computing for sr=2117 and t=11656.393...
# Computing for sr=2140 and t=11656.393...
# Computing for sr=2163 and t=11656.393...
# Computing for sr=2186 and t=11656.393...
# Computing for sr=2209 and t=11656.393...
# Computing for sr=2232 and t=11656.393...
# Computing for sr=2255 and t=11656.393...
# Computing for sr=2278 and t=11656.393...
# Computing for sr=2301 and t=11656.393...
# Computing for sr=1 and t=1020.000...
# Computing for sr=2 and t=1020.000...
# Computing for sr=3 and t=1020.000...
# Computing for sr=4 and t=1020.000...
# Computing for sr=5 and t=1020.000...
# Computing for sr=6 and t=1020.000...
# Computing for sr=7 and t=1020.000...
# Computing for sr=8 and t=1020.000...
# Computing for sr=9 and t=1020.000...
# Computing for sr=10 and t=1020.000...
# Computing for sr=11 and t=1020.000...
# Computing for sr=12 and t=1020.000...
# Computing for sr=13 and t=1020.000...
# Computing for sr=14 and t=1020.000...
# Computing for sr=15 and t=1020.000...
# Computing for sr=16 and t=1020.000...
# Computing for sr=17 and t=1020.000...
# Computing for sr=18 and t=1020.000...
# Computing for sr=19 and t=1020.000...
# Computing for sr=20 and t=1020.000...
# Computing for sr=21 and t=1020.000...
# Computing for sr=22 and t=1020.000...
# Computing for sr=23 and t=1020.000...
# Computing for sr=24 and t=1020.000...
# Computing for sr=25 and t=1020.000...
# Computing for sr=26 and t=1020.000...
# Computing for sr=27 and t=1020.000...
# Computing for sr=28 and t=1020.000...
# Computing for sr=29 and t=1020.000...
# Computing for sr=30 and t=1020.000...
# Computing for sr=31 and t=1020.000...
# Computing for sr=32 and t=1020.000...
# Computing for sr=33 and t=1020.000...
# Computing for sr=34 and t=1020.000...
# Computing for sr=35 and t=1020.000...
# Computing for sr=36 and t=1020.000...
# Computing for sr=37 and t=1020.000...
# Computing for sr=38 and t=1020.000...
# Computing for sr=39 and t=1020.000...
# Computing for sr=40 and t=1020.000...
# Computing for sr=41 and t=1020.000...
# Computing for sr=42 and t=1020.000...
# Computing for sr=43 and t=1020.000...
# Computing for sr=44 and t=1020.000...
# Computing for sr=45 and t=1020.000...
# Computing for sr=46 and t=1020.000...
# Computing for sr=47 and t=1020.000...
# Computing for sr=48 and t=1020.000...
# Computing for sr=49 and t=1020.000...
# Computing for sr=50 and t=1020.000...
# Computing for sr=51 and t=1020.000...
# Computing for sr=52 and t=1020.000...
# Computing for sr=53 and t=1020.000...
# Computing for sr=54 and t=1020.000...
# Computing for sr=55 and t=1020.000...
# Computing for sr=56 and t=1020.000...
# Computing for sr=57 and t=1020.000...
# Computing for sr=58 and t=1020.000...
# Computing for sr=59 and t=1020.000...
# Computing for sr=60 and t=1020.000...
# Computing for sr=61 and t=1020.000...
# Computing for sr=62 and t=1020.000...
# Computing for sr=63 and t=1020.000...
# Computing for sr=64 and t=1020.000...
# Computing for sr=65 and t=1020.000...
# Computing for sr=66 and t=1020.000...
# Computing for sr=67 and t=1020.000...
# Computing for sr=68 and t=1020.000...
# Computing for sr=69 and t=1020.000...
# Computing for sr=70 and t=1020.000...
# Computing for sr=71 and t=1020.000...
# Computing for sr=72 and t=1020.000...
# Computing for sr=73 and t=1020.000...
# Computing for sr=74 and t=1020.000...
# Computing for sr=75 and t=1020.000...
# Computing for sr=76 and t=1020.000...
# Computing for sr=77 and t=1020.000...
# Computing for sr=78 and t=1020.000...
# Computing for sr=79 and t=1020.000...
# Computing for sr=80 and t=1020.000...
# Computing for sr=81 and t=1020.000...
# Computing for sr=82 and t=1020.000...
# Computing for sr=83 and t=1020.000...
# Computing for sr=84 and t=1020.000...
# Computing for sr=85 and t=1020.000...
# Computing for sr=86 and t=1020.000...
# Computing for sr=87 and t=1020.000...
# Computing for sr=88 and t=1020.000...
# Computing for sr=89 and t=1020.000...
# Computing for sr=90 and t=1020.000...
# Computing for sr=91 and t=1020.000...
# Computing for sr=92 and t=1020.000...
# Computing for sr=93 and t=1020.000...
# Computing for sr=94 and t=1020.000...
# Computing for sr=95 and t=1020.000...
# Computing for sr=96 and t=1020.000...
# Computing for sr=97 and t=1020.000...
# Computing for sr=98 and t=1020.000...
# Computing for sr=99 and t=1020.000...
# Computing for sr=100 and t=1020.000...
# Computing for sr=101 and t=1020.000...
# Computing for sr=102 and t=1020.000...
# Computing for sr=103 and t=1020.000...
# Computing for sr=104 and t=1020.000...
# Computing for sr=105 and t=1020.000...
# Computing for sr=106 and t=1020.000...
# Computing for sr=107 and t=1020.000...
# Computing for sr=108 and t=1020.000...
# Computing for sr=109 and t=1020.000...
# Computing for sr=110 and t=1020.000...
# Computing for sr=111 and t=1020.000...
# Computing for sr=112 and t=1020.000...
# Computing for sr=113 and t=1020.000...
# Computing for sr=114 and t=1020.000...
# Computing for sr=115 and t=1020.000...
# Computing for sr=116 and t=1020.000...
# Computing for sr=117 and t=1020.000...
# Computing for sr=118 and t=1020.000...
# Computing for sr=119 and t=1020.000...
# Computing for sr=120 and t=1020.000...
# Computing for sr=121 and t=1020.000...
# Computing for sr=122 and t=1020.000...
# Computing for sr=123 and t=1020.000...
# Computing for sr=124 and t=1020.000...
# Computing for sr=125 and t=1020.000...
# Computing for sr=126 and t=1020.000...
# Computing for sr=127 and t=1020.000...
# Computing for sr=128 and t=1020.000...
# Computing for sr=129 and t=1020.000...
# Computing for sr=130 and t=1020.000...
# Computing for sr=131 and t=1020.000...
# Computing for sr=132 and t=1020.000...
# Computing for sr=133 and t=1020.000...
# Computing for sr=134 and t=1020.000...
# Computing for sr=135 and t=1020.000...
# Computing for sr=136 and t=1020.000...
# Computing for sr=137 and t=1020.000...
# Computing for sr=138 and t=1020.000...
# Computing for sr=139 and t=1020.000...
# Computing for sr=140 and t=1020.000...
# Computing for sr=141 and t=1020.000...
# Computing for sr=142 and t=1020.000...
# Computing for sr=143 and t=1020.000...
# Computing for sr=144 and t=1020.000...
# Computing for sr=145 and t=1020.000...
# Computing for sr=146 and t=1020.000...
# Computing for sr=147 and t=1020.000...
# Computing for sr=148 and t=1020.000...
# Computing for sr=149 and t=1020.000...
# Computing for sr=150 and t=1020.000...
# Computing for sr=151 and t=1020.000...
# Computing for sr=152 and t=1020.000...
# Computing for sr=153 and t=1020.000...
# Computing for sr=154 and t=1020.000...
# Computing for sr=155 and t=1020.000...
# Computing for sr=156 and t=1020.000...
# Computing for sr=157 and t=1020.000...
# Computing for sr=158 and t=1020.000...
# Computing for sr=159 and t=1020.000...
# Computing for sr=160 and t=1020.000...
# Computing for sr=161 and t=1020.000...
# Computing for sr=162 and t=1020.000...
# Computing for sr=163 and t=1020.000...
# Computing for sr=164 and t=1020.000...
# Computing for sr=165 and t=1020.000...
# Computing for sr=166 and t=1020.000...
# Computing for sr=167 and t=1020.000...
# Computing for sr=168 and t=1020.000...
# Computing for sr=169 and t=1020.000...
# Computing for sr=170 and t=1020.000...
# Computing for sr=171 and t=1020.000...
# Computing for sr=172 and t=1020.000...
# Computing for sr=173 and t=1020.000...
# Computing for sr=174 and t=1020.000...
# Computing for sr=175 and t=1020.000...
# Computing for sr=176 and t=1020.000...
# Computing for sr=177 and t=1020.000...
# Computing for sr=178 and t=1020.000...
# Computing for sr=179 and t=1020.000...
# Computing for sr=180 and t=1020.000...
# Computing for sr=181 and t=1020.000...
# Computing for sr=182 and t=1020.000...
# Computing for sr=183 and t=1020.000...
# Computing for sr=184 and t=1020.000...
# Computing for sr=185 and t=1020.000...
# Computing for sr=186 and t=1020.000...
# Computing for sr=187 and t=1020.000...
# Computing for sr=188 and t=1020.000...
# Computing for sr=189 and t=1020.000...
# Computing for sr=190 and t=1020.000...
# Computing for sr=191 and t=1020.000...
# Computing for sr=192 and t=1020.000...
# Computing for sr=1 and t=1230.000...
# Computing for sr=2 and t=1230.000...
# Computing for sr=3 and t=1230.000...
# Computing for sr=4 and t=1230.000...
# Computing for sr=5 and t=1230.000...
# Computing for sr=6 and t=1230.000...
# Computing for sr=7 and t=1230.000...
# Computing for sr=8 and t=1230.000...
# Computing for sr=9 and t=1230.000...
# Computing for sr=10 and t=1230.000...
# Computing for sr=11 and t=1230.000...
# Computing for sr=12 and t=1230.000...
# Computing for sr=13 and t=1230.000...
# Computing for sr=14 and t=1230.000...
# Computing for sr=15 and t=1230.000...
# Computing for sr=16 and t=1230.000...
# Computing for sr=17 and t=1230.000...
# Computing for sr=18 and t=1230.000...
# Computing for sr=19 and t=1230.000...
# Computing for sr=20 and t=1230.000...
# Computing for sr=21 and t=1230.000...
# Computing for sr=22 and t=1230.000...
# Computing for sr=23 and t=1230.000...
# Computing for sr=24 and t=1230.000...
# Computing for sr=25 and t=1230.000...
# Computing for sr=26 and t=1230.000...
# Computing for sr=27 and t=1230.000...
# Computing for sr=28 and t=1230.000...
# Computing for sr=29 and t=1230.000...
# Computing for sr=30 and t=1230.000...
# Computing for sr=31 and t=1230.000...
# Computing for sr=32 and t=1230.000...
# Computing for sr=33 and t=1230.000...
# Computing for sr=34 and t=1230.000...
# Computing for sr=35 and t=1230.000...
# Computing for sr=36 and t=1230.000...
# Computing for sr=37 and t=1230.000...
# Computing for sr=38 and t=1230.000...
# Computing for sr=39 and t=1230.000...
# Computing for sr=40 and t=1230.000...
# Computing for sr=41 and t=1230.000...
# Computing for sr=42 and t=1230.000...
# Computing for sr=43 and t=1230.000...
# Computing for sr=44 and t=1230.000...
# Computing for sr=45 and t=1230.000...
# Computing for sr=46 and t=1230.000...
# Computing for sr=47 and t=1230.000...
# Computing for sr=48 and t=1230.000...
# Computing for sr=49 and t=1230.000...
# Computing for sr=50 and t=1230.000...
# Computing for sr=51 and t=1230.000...
# Computing for sr=52 and t=1230.000...
# Computing for sr=53 and t=1230.000...
# Computing for sr=54 and t=1230.000...
# Computing for sr=55 and t=1230.000...
# Computing for sr=56 and t=1230.000...
# Computing for sr=57 and t=1230.000...
# Computing for sr=58 and t=1230.000...
# Computing for sr=59 and t=1230.000...
# Computing for sr=60 and t=1230.000...
# Computing for sr=61 and t=1230.000...
# Computing for sr=62 and t=1230.000...
# Computing for sr=63 and t=1230.000...
# Computing for sr=64 and t=1230.000...
# Computing for sr=65 and t=1230.000...
# Computing for sr=66 and t=1230.000...
# Computing for sr=67 and t=1230.000...
# Computing for sr=68 and t=1230.000...
# Computing for sr=69 and t=1230.000...
# Computing for sr=70 and t=1230.000...
# Computing for sr=71 and t=1230.000...
# Computing for sr=72 and t=1230.000...
# Computing for sr=73 and t=1230.000...
# Computing for sr=74 and t=1230.000...
# Computing for sr=75 and t=1230.000...
# Computing for sr=76 and t=1230.000...
# Computing for sr=77 and t=1230.000...
# Computing for sr=78 and t=1230.000...
# Computing for sr=79 and t=1230.000...
# Computing for sr=80 and t=1230.000...
# Computing for sr=81 and t=1230.000...
# Computing for sr=82 and t=1230.000...
# Computing for sr=83 and t=1230.000...
# Computing for sr=84 and t=1230.000...
# Computing for sr=85 and t=1230.000...
# Computing for sr=86 and t=1230.000...
# Computing for sr=87 and t=1230.000...
# Computing for sr=88 and t=1230.000...
# Computing for sr=89 and t=1230.000...
# Computing for sr=90 and t=1230.000...
# Computing for sr=91 and t=1230.000...
# Computing for sr=92 and t=1230.000...
# Computing for sr=93 and t=1230.000...
# Computing for sr=94 and t=1230.000...
# Computing for sr=95 and t=1230.000...
# Computing for sr=96 and t=1230.000...
# Computing for sr=97 and t=1230.000...
# Computing for sr=98 and t=1230.000...
# Computing for sr=99 and t=1230.000...
# Computing for sr=100 and t=1230.000...
# Computing for sr=101 and t=1230.000...
# Computing for sr=102 and t=1230.000...
# Computing for sr=103 and t=1230.000...
# Computing for sr=104 and t=1230.000...
# Computing for sr=105 and t=1230.000...
# Computing for sr=106 and t=1230.000...
# Computing for sr=107 and t=1230.000...
# Computing for sr=108 and t=1230.000...
# Computing for sr=109 and t=1230.000...
# Computing for sr=110 and t=1230.000...
# Computing for sr=111 and t=1230.000...
# Computing for sr=112 and t=1230.000...
# Computing for sr=113 and t=1230.000...
# Computing for sr=114 and t=1230.000...
# Computing for sr=115 and t=1230.000...
# Computing for sr=116 and t=1230.000...
# Computing for sr=117 and t=1230.000...
# Computing for sr=118 and t=1230.000...
# Computing for sr=119 and t=1230.000...
# Computing for sr=120 and t=1230.000...
# Computing for sr=121 and t=1230.000...
# Computing for sr=122 and t=1230.000...
# Computing for sr=123 and t=1230.000...
# Computing for sr=124 and t=1230.000...
# Computing for sr=125 and t=1230.000...
# Computing for sr=126 and t=1230.000...
# Computing for sr=127 and t=1230.000...
# Computing for sr=128 and t=1230.000...
# Computing for sr=129 and t=1230.000...
# Computing for sr=130 and t=1230.000...
# Computing for sr=131 and t=1230.000...
# Computing for sr=132 and t=1230.000...
# Computing for sr=133 and t=1230.000...
# Computing for sr=134 and t=1230.000...
# Computing for sr=135 and t=1230.000...
# Computing for sr=136 and t=1230.000...
# Computing for sr=137 and t=1230.000...
# Computing for sr=138 and t=1230.000...
# Computing for sr=139 and t=1230.000...
# Computing for sr=140 and t=1230.000...
# Computing for sr=141 and t=1230.000...
# Computing for sr=142 and t=1230.000...
# Computing for sr=143 and t=1230.000...
# Computing for sr=144 and t=1230.000...
# Computing for sr=145 and t=1230.000...
# Computing for sr=146 and t=1230.000...
# Computing for sr=147 and t=1230.000...
# Computing for sr=148 and t=1230.000...
# Computing for sr=149 and t=1230.000...
# Computing for sr=150 and t=1230.000...
# Computing for sr=151 and t=1230.000...
# Computing for sr=152 and t=1230.000...
# Computing for sr=153 and t=1230.000...
# Computing for sr=154 and t=1230.000...
# Computing for sr=155 and t=1230.000...
# Computing for sr=156 and t=1230.000...
# Computing for sr=157 and t=1230.000...
# Computing for sr=158 and t=1230.000...
# Computing for sr=159 and t=1230.000...
# Computing for sr=160 and t=1230.000...
# Computing for sr=161 and t=1230.000...
# Computing for sr=162 and t=1230.000...
# Computing for sr=163 and t=1230.000...
# Computing for sr=164 and t=1230.000...
# Computing for sr=165 and t=1230.000...
# Computing for sr=166 and t=1230.000...
# Computing for sr=167 and t=1230.000...
# Computing for sr=168 and t=1230.000...
# Computing for sr=169 and t=1230.000...
# Computing for sr=170 and t=1230.000...
# Computing for sr=171 and t=1230.000...
# Computing for sr=172 and t=1230.000...
# Computing for sr=173 and t=1230.000...
# Computing for sr=174 and t=1230.000...
# Computing for sr=175 and t=1230.000...
# Computing for sr=176 and t=1230.000...
# Computing for sr=177 and t=1230.000...
# Computing for sr=178 and t=1230.000...
# Computing for sr=179 and t=1230.000...
# Computing for sr=180 and t=1230.000...
# Computing for sr=181 and t=1230.000...
# Computing for sr=182 and t=1230.000...
# Computing for sr=183 and t=1230.000...
# Computing for sr=184 and t=1230.000...
# Computing for sr=185 and t=1230.000...
# Computing for sr=186 and t=1230.000...
# Computing for sr=187 and t=1230.000...
# Computing for sr=188 and t=1230.000...
# Computing for sr=189 and t=1230.000...
# Computing for sr=190 and t=1230.000...
# Computing for sr=191 and t=1230.000...
# Computing for sr=192 and t=1230.000...
# Computing for sr=1 and t=1980.000...
# Computing for sr=2 and t=1980.000...
# Computing for sr=3 and t=1980.000...
# Computing for sr=4 and t=1980.000...
# Computing for sr=5 and t=1980.000...
# Computing for sr=6 and t=1980.000...
# Computing for sr=7 and t=1980.000...
# Computing for sr=8 and t=1980.000...
# Computing for sr=9 and t=1980.000...
# Computing for sr=10 and t=1980.000...
# Computing for sr=11 and t=1980.000...
# Computing for sr=12 and t=1980.000...
# Computing for sr=13 and t=1980.000...
# Computing for sr=14 and t=1980.000...
# Computing for sr=15 and t=1980.000...
# Computing for sr=16 and t=1980.000...
# Computing for sr=17 and t=1980.000...
# Computing for sr=18 and t=1980.000...
# Computing for sr=19 and t=1980.000...
# Computing for sr=20 and t=1980.000...
# Computing for sr=21 and t=1980.000...
# Computing for sr=22 and t=1980.000...
# Computing for sr=23 and t=1980.000...
# Computing for sr=24 and t=1980.000...
# Computing for sr=25 and t=1980.000...
# Computing for sr=26 and t=1980.000...
# Computing for sr=27 and t=1980.000...
# Computing for sr=28 and t=1980.000...
# Computing for sr=29 and t=1980.000...
# Computing for sr=30 and t=1980.000...
# Computing for sr=31 and t=1980.000...
# Computing for sr=32 and t=1980.000...
# Computing for sr=33 and t=1980.000...
# Computing for sr=34 and t=1980.000...
# Computing for sr=35 and t=1980.000...
# Computing for sr=36 and t=1980.000...
# Computing for sr=37 and t=1980.000...
# Computing for sr=38 and t=1980.000...
# Computing for sr=39 and t=1980.000...
# Computing for sr=40 and t=1980.000...
# Computing for sr=41 and t=1980.000...
# Computing for sr=42 and t=1980.000...
# Computing for sr=43 and t=1980.000...
# Computing for sr=44 and t=1980.000...
# Computing for sr=45 and t=1980.000...
# Computing for sr=46 and t=1980.000...
# Computing for sr=47 and t=1980.000...
# Computing for sr=48 and t=1980.000...
# Computing for sr=49 and t=1980.000...
# Computing for sr=50 and t=1980.000...
# Computing for sr=51 and t=1980.000...
# Computing for sr=52 and t=1980.000...
# Computing for sr=53 and t=1980.000...
# Computing for sr=54 and t=1980.000...
# Computing for sr=55 and t=1980.000...
# Computing for sr=56 and t=1980.000...
# Computing for sr=57 and t=1980.000...
# Computing for sr=58 and t=1980.000...
# Computing for sr=59 and t=1980.000...
# Computing for sr=60 and t=1980.000...
# Computing for sr=61 and t=1980.000...
# Computing for sr=62 and t=1980.000...
# Computing for sr=63 and t=1980.000...
# Computing for sr=64 and t=1980.000...
# Computing for sr=65 and t=1980.000...
# Computing for sr=66 and t=1980.000...
# Computing for sr=67 and t=1980.000...
# Computing for sr=68 and t=1980.000...
# Computing for sr=69 and t=1980.000...
# Computing for sr=70 and t=1980.000...
# Computing for sr=71 and t=1980.000...
# Computing for sr=72 and t=1980.000...
# Computing for sr=73 and t=1980.000...
# Computing for sr=74 and t=1980.000...
# Computing for sr=75 and t=1980.000...
# Computing for sr=76 and t=1980.000...
# Computing for sr=77 and t=1980.000...
# Computing for sr=78 and t=1980.000...
# Computing for sr=79 and t=1980.000...
# Computing for sr=80 and t=1980.000...
# Computing for sr=81 and t=1980.000...
# Computing for sr=82 and t=1980.000...
# Computing for sr=83 and t=1980.000...
# Computing for sr=84 and t=1980.000...
# Computing for sr=85 and t=1980.000...
# Computing for sr=86 and t=1980.000...
# Computing for sr=87 and t=1980.000...
# Computing for sr=88 and t=1980.000...
# Computing for sr=89 and t=1980.000...
# Computing for sr=90 and t=1980.000...
# Computing for sr=91 and t=1980.000...
# Computing for sr=92 and t=1980.000...
# Computing for sr=93 and t=1980.000...
# Computing for sr=94 and t=1980.000...
# Computing for sr=95 and t=1980.000...
# Computing for sr=96 and t=1980.000...
# Computing for sr=97 and t=1980.000...
# Computing for sr=98 and t=1980.000...
# Computing for sr=99 and t=1980.000...
# Computing for sr=100 and t=1980.000...
# Computing for sr=101 and t=1980.000...
# Computing for sr=102 and t=1980.000...
# Computing for sr=103 and t=1980.000...
# Computing for sr=104 and t=1980.000...
# Computing for sr=105 and t=1980.000...
# Computing for sr=106 and t=1980.000...
# Computing for sr=107 and t=1980.000...
# Computing for sr=108 and t=1980.000...
# Computing for sr=109 and t=1980.000...
# Computing for sr=110 and t=1980.000...
# Computing for sr=111 and t=1980.000...
# Computing for sr=112 and t=1980.000...
# Computing for sr=113 and t=1980.000...
# Computing for sr=114 and t=1980.000...
# Computing for sr=115 and t=1980.000...
# Computing for sr=116 and t=1980.000...
# Computing for sr=117 and t=1980.000...
# Computing for sr=118 and t=1980.000...
# Computing for sr=119 and t=1980.000...
# Computing for sr=120 and t=1980.000...
# Computing for sr=121 and t=1980.000...
# Computing for sr=122 and t=1980.000...
# Computing for sr=123 and t=1980.000...
# Computing for sr=124 and t=1980.000...
# Computing for sr=125 and t=1980.000...
# Computing for sr=126 and t=1980.000...
# Computing for sr=127 and t=1980.000...
# Computing for sr=128 and t=1980.000...
# Computing for sr=129 and t=1980.000...
# Computing for sr=130 and t=1980.000...
# Computing for sr=131 and t=1980.000...
# Computing for sr=132 and t=1980.000...
# Computing for sr=133 and t=1980.000...
# Computing for sr=134 and t=1980.000...
# Computing for sr=135 and t=1980.000...
# Computing for sr=136 and t=1980.000...
# Computing for sr=137 and t=1980.000...
# Computing for sr=138 and t=1980.000...
# Computing for sr=139 and t=1980.000...
# Computing for sr=140 and t=1980.000...
# Computing for sr=141 and t=1980.000...
# Computing for sr=142 and t=1980.000...
# Computing for sr=143 and t=1980.000...
# Computing for sr=144 and t=1980.000...
# Computing for sr=145 and t=1980.000...
# Computing for sr=146 and t=1980.000...
# Computing for sr=147 and t=1980.000...
# Computing for sr=148 and t=1980.000...
# Computing for sr=149 and t=1980.000...
# Computing for sr=150 and t=1980.000...
# Computing for sr=151 and t=1980.000...
# Computing for sr=152 and t=1980.000...
# Computing for sr=153 and t=1980.000...
# Computing for sr=154 and t=1980.000...
# Computing for sr=155 and t=1980.000...
# Computing for sr=156 and t=1980.000...
# Computing for sr=157 and t=1980.000...
# Computing for sr=158 and t=1980.000...
# Computing for sr=159 and t=1980.000...
# Computing for sr=160 and t=1980.000...
# Computing for sr=161 and t=1980.000...
# Computing for sr=162 and t=1980.000...
# Computing for sr=163 and t=1980.000...
# Computing for sr=164 and t=1980.000...
# Computing for sr=165 and t=1980.000...
# Computing for sr=166 and t=1980.000...
# Computing for sr=167 and t=1980.000...
# Computing for sr=168 and t=1980.000...
# Computing for sr=169 and t=1980.000...
# Computing for sr=170 and t=1980.000...
# Computing for sr=171 and t=1980.000...
# Computing for sr=172 and t=1980.000...
# Computing for sr=173 and t=1980.000...
# Computing for sr=174 and t=1980.000...
# Computing for sr=175 and t=1980.000...
# Computing for sr=176 and t=1980.000...
# Computing for sr=177 and t=1980.000...
# Computing for sr=178 and t=1980.000...
# Computing for sr=179 and t=1980.000...
# Computing for sr=180 and t=1980.000...
# Computing for sr=181 and t=1980.000...
# Computing for sr=182 and t=1980.000...
# Computing for sr=183 and t=1980.000...
# Computing for sr=184 and t=1980.000...
# Computing for sr=185 and t=1980.000...
# Computing for sr=186 and t=1980.000...
# Computing for sr=187 and t=1980.000...
# Computing for sr=188 and t=1980.000...
# Computing for sr=189 and t=1980.000...
# Computing for sr=190 and t=1980.000...
# Computing for sr=191 and t=1980.000...
# Computing for sr=192 and t=1980.000...

# %%
if not os.path.exists(resultPath):
    try:
        os.makedirs(resultPath)
    except OSError as exc: # Guard against race condition
        if exc.errno != errno.EEXIST:
            raise

for k,filename in enumerate(filenames):
    for o in oracle:
        # !Rscript ./helpers/2.calculateMetrics.R ./data_clustered/{o}/{o}-{filename}.csv {n_lines[k]} {resultPath}
